# %%
import os
import sys

sys.path.append(os.path.dirname(os.getcwd()))
import dir_path
import pandas as pd

# %%
df = pd.read_csv(dir_path.path.data_dir + '/12_19_교통사고정보.csv',encoding='utf-8')

# %%
df

# %%
df

# %%
# 글자 변환


# 미리정의 


from enum import Enum


class transform(Enum):
    child = '어린이사고'
    bicycle = '자전거사고'
    dawn = '야간사고'
    old = '노인사고'
    pedestrian = '보행자사고'
    ##################
    code = '법정동코드'
    cases = '사고건수'
    cases_ratio = '사고건수 구성비'
    die = '사망자수'
    dieratio = '사망자수 구성비'
    fatality = '치사율'
    lnjured = '부상자수'
    lnjuredratio = '부상자수 구성비'

# %%
transform.bicycle.value

# %%
import ENUM
import pandas as pd
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))#ipynb용
import dir_path

# %%
#메인테스트 메소드

def main(kind :str , year : int, doc :str):
    
    df = pd.read_csv(dir_path.path.data_dir + '/12_19_교통사고정보.csv',encoding='utf-8')
    trans = list(ENUM.transform)


    kind_list = df['대상사고 구분명'] == ENUM.transform[kind].value
    year_list = df['연도'] == year
    doc = ENUM.transform[doc].value
    return df[kind_list & year_list][doc].to_dict()

# %%
main('pedestrian',2012,'die')
# Out:
# {2: 9,
#  7: 8,
#  12: 6,
#  17: 4,
#  22: 10,
#  27: 8,
#  32: 10,
#  37: 13,
#  42: 4,
#  47: 12,
#  52: 14,
#  57: 10,
#  62: 19,
#  67: 7,
#  72: 11,
#  77: 15,
#  82: 10,
#  87: 6,
#  92: 13,
#  97: 8,
#  102: 9,
#  107: 10,
#  112: 8,
#  117: 5,
#  122: 13,
#  127: 3,
#  132: 2,
#  137: 5,
#  142: 4,
#  147: 17,
#  152: 5,
#  157: 12,
#  162: 8,
#  167: 9,
#  172: 7,
#  177: 7,
#  182: 9,
#  187: 5,
#  192: 3,
#  197: 15,
#  202: 3,
#  207: 36,
#  212: 22,
#  217: 17,
#  222: 17,
#  227: 13,
#  232: 15,
#  237: 24,
#  242: 10,
#  247: 3,
#  252: 9,
#  257: 7,
#  262: 23,
#  267: 16,
#  272: 13,
#  277: 27,
#  282: 6,
#  287: 3,
#  292: 11,
#  297: 4,
#  302: 5,
#  307: 10,
#  312: 27,
#  317: 15,
#  322: 17,
#  327: 4,
#  332: 1,
#  337: 5,
#  342: 21,
#  347: 4,
#  352: 3,
#  357: 4,
#  362: 8,
#  367: 23,
#  372: 2,
#  377: 13,
#  382: 0,
#  387: 3,
#  392: 3,
#  397: 5,
#  402: 4,
#  407: 3,
#  412: 1,
#  417: 2,
#  422: 3,
#  427: 0,
#  432: 2,
#  437: 5,
#  441: 2,
# ...

# %%
 '어린이사고'
list_2018 = df['연도'] == 2018 
# 반환 예정값
print(df[child_list & list_2018]['법정동코드'].to_dict())

# %%
acc 
for i in acc_list:

# %%
df
